# %% [markdown]
# <a href="https://colab.research.google.com/github/sairohan031/STML_LAB/blob/main/STML_LAB9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/breast_cancer_survival (1).csv')
data.head()
print(data.head())
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0   42  FEMALE   0.95256   2.15000  0.007972 -0.048340           II
# 1   54  FEMALE   0.00000   1.38020 -0.498030 -0.507320           II
# 2   63  FEMALE  -0.52303   1.76400 -0.370190  0.010815           II
# 3   78  FEMALE  -0.87618   0.12943 -0.370380  0.132190            I
# 4   42  FEMALE   0.22611   1.74910 -0.543970 -0.390210           II
#
#                        Histology ER status PR status HER2 status Surgery_type  \
# 0  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 1  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 2  Infiltrating Ductal Carcinoma  Positive  Positive    Negative   Lumpectomy
# 3  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 4  Infiltrating Ductal Carcinoma  Positive  Positive    Positive   Lumpectomy
#
#   Date_of_Surgery Date_of_Last_Visit Patient_Status
# ...

# %%
features = data.drop(columns=['Patient_Status'])
target = data['Patient_Status']
print("Features:")
print(features.head())
print("\nTarget Variable:")
print(target.head())
# Out:
# Features:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0   42  FEMALE   0.95256   2.15000  0.007972 -0.048340           II
# 1   54  FEMALE   0.00000   1.38020 -0.498030 -0.507320           II
# 2   63  FEMALE  -0.52303   1.76400 -0.370190  0.010815           II
# 3   78  FEMALE  -0.87618   0.12943 -0.370380  0.132190            I
# 4   42  FEMALE   0.22611   1.74910 -0.543970 -0.390210           II
#
#                        Histology ER status PR status HER2 status Surgery_type  \
# 0  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 1  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 2  Infiltrating Ductal Carcinoma  Positive  Positive    Negative   Lumpectomy
# 3  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 4  Infiltrating Ductal Carcinoma  Positive  Positive    Positive   Lumpectomy
#
#   Date_of_Surgery Date_of_Last_Visit
# 0       20-May-18          26-Aug-18
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
target_encoded = label_encoder.fit_transform(target)
features_encoded = pd.get_dummies(features, drop_first=True)
print("Encoded Features:")
print(features_encoded.head())
print("\nEncoded Target Variable:")
print(target_encoded[:5])
# Out:
# Encoded Features:
#    Age  Protein1  Protein2  Protein3  Protein4  Gender_MALE  Tumour_Stage_II  \
# 0   42   0.95256   2.15000  0.007972 -0.048340        False             True
# 1   54   0.00000   1.38020 -0.498030 -0.507320        False             True
# 2   63  -0.52303   1.76400 -0.370190  0.010815        False             True
# 3   78  -0.87618   0.12943 -0.370380  0.132190        False            False
# 4   42   0.22611   1.74910 -0.543970 -0.390210        False             True
#
#    Tumour_Stage_III  Histology_Infiltrating Lobular Carcinoma  \
# 0             False                                     False
# 1             False                                     False
# 2             False                                     False
# 3             False                                     False
# 4             False                                     False
#
#    Histology_Mucinous Carcinoma  ...  Date_of_Last_Visit_29-Jan-19  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
X_train, X_test, y_train, y_test = train_test_split(features_encoded, target_encoded, test_size=0.2, random_state=42)
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
test_sizes = [0.1, 0.2, 0.3]
for size in test_sizes:
    X_train, X_test, y_train, y_test = train_test_split(features_encoded, target_encoded, test_size=size, random_state=42)
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    print(f'Accuracy with test size {size}: {accuracy:.2f}')
# Out:
# Accuracy with test size 0.1: 0.74
# Accuracy with test size 0.2: 0.78
# Accuracy with test size 0.3: 0.78
