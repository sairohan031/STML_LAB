# %% [markdown]
# <a href="https://colab.research.google.com/github/sairohan031/STML_LAB/blob/main/STML_PROJECT_2303A52025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Data-set

# %% [markdown]
# Importing the necessary modules

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Importing the data-set

# %%
data1 = pd.read_csv('/content/mountains_vs_beaches_preferences (1).csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Converting the Data-set into a data-frame

# %%
df1 = pd.DataFrame(data1)
df1
# Out:
#        Age      Gender  Income Education_Level  Travel_Frequency  \
# 0       56        male   71477        bachelor                 9
# 1       69        male   88740          master                 1
# 2       46      female   46562          master                 0
# 3       32  non-binary   99044     high school                 6
# 4       60      female  106583     high school                 5
# ...    ...         ...     ...             ...               ...
# 52439   67      female   85325          master                 3
# 52440   37      female  110346        bachelor                 7
# 52441   53  non-binary   71080       doctorate                 7
# 52442   40      female   75174       doctorate                 9
# 52443   33  non-binary   34475          master                 6
#
#       Preferred_Activities  Vacation_Budget  Location  Proximity_to_Mountains  \
# 0                   skiing             2477     urban                     175
# 1                 swimming             4777  suburban                     228
# 2                   skiing             1469     urban                      71
# 3                   hiking             1482     rural                      31
# 4               sunbathing              516  suburban                      23
# ...                    ...              ...       ...                     ...
# 52439               hiking             1762  suburban                      51
# 52440             swimming             1676     urban                     259
# 52441             swimming             3877     urban                     164
# 52442             swimming             4620  suburban                     173
# 52443               hiking              928  suburban                     218
#
#        Proximity_to_Beaches Favorite_Season  Pets  Environmental_Concerns  \
# 0                       267          summer     0                       1
# 1                       190            fall     0                       1
# 2                       280          winter     0                       0
# 3                       255          summer     1                       0
# 4                       151          winter     1                       1
# ...                     ...             ...   ...                     ...
# 52439                   262            fall     1                       0
# 52440                    84          spring     1                       0
# 52441                    27            fall     0                       1
# 52442                    10          summer     0                       1
# 52443                   166          spring     1                       0
#
#        Preference
# 0               1
# 1               0
# 2               1
# 3               1
# 4               0
# ...           ...
# 52439           1
# 52440           0
# 52441           0
# 52442           0
# 52443           0
#
# [52444 rows x 14 columns]

# %% [markdown]
# Now, Dropping few unnecessary features

# %%
from sklearn.utils import shuffle
df1 = shuffle(df1)
df1.head()
# Out:
#        Age  Gender  Income Education_Level  Travel_Frequency  \
# 29342   38  female   34215       doctorate                 9
# 6717    28    male   55820       doctorate                 3
# 39252   18    male  105777        bachelor                 0
# 24138   50    male   61515          master                 3
# 45746   57    male   64102       doctorate                 5
#
#       Preferred_Activities  Vacation_Budget Location  Proximity_to_Mountains  \
# 29342               hiking             3444    urban                      67
# 6717                skiing             1190    rural                     261
# 39252           sunbathing             2888    rural                     225
# 24138             swimming             1987    rural                     286
# 45746           sunbathing             2692    urban                     198
#
#        Proximity_to_Beaches Favorite_Season  Pets  Environmental_Concerns  \
# 29342                    46            fall     0                       0
# 6717                     56            fall     1                       1
# 39252                   282          summer     1                       0
# 24138                   140            fall     0                       0
# 45746                   245          spring     0                       1
#
#        Preference
# 29342           0
# 6717            0
# 39252           0
# 24138           0
# 45746           0

# %% [markdown]
# Declaring Variables than zipping them into a Array.

# %%
x0 = 1
x1 = df1['Age']
x2 = df1['Gender']
x3 = df1['Income']
x4 = df1['Education_Level']
x5 = df1['Preferred_Activities']
x6 = df1['Travel_Frequency']
x7 = df1['Vacation_Budget']
x8 = df1['Location']
x9 = df1['Proximity_to_Mountains']
x10 = df1['Proximity_to_Beaches']
x11 = df1['Favorite_Season']
x12 = df1['Pets']
x13 = df1['Environmental_Concerns']

#Target-Variable.
y = df1['Preference']

# %% [markdown]
# Mapping the Variables and finding the unique elements

# %%
import pandas as pd

unique_elements = {}
columns = ['Age', 'Gender', 'Income', 'Education_Level', 'Preferred_Activities', 'Travel_Frequency', 'Vacation_Budget', 'Location', 'Proximity_to_Mountains', 'Proximity_to_Beaches', 'Favorite_Season', 'Pets', 'Environmental_Concerns', 'Preference']

for column in columns:
    unique_elements[column] = df1[column].unique()

for column, unique_values in unique_elements.items():
    print(f"Unique elements in {column}:", unique_values)
# Out:
# Unique elements in Age: [38 28 18 50 57 45 23 22 51 43 65 62 54 44 64 39 56 48 33 30 19 59 36 52
#  27 37 20 42 68 31 49 34 61 21 46 25 69 24 40 60 58 67 26 55 63 29 32 53
#  41 47 66 35]
# Unique elements in Gender: ['female' 'male' 'non-binary']
# Unique elements in Income: [ 34215  55820 105777 ...  84412  74638  40650]
# Unique elements in Education_Level: ['doctorate' 'bachelor' 'master' 'high school']
# Unique elements in Preferred_Activities: ['hiking' 'skiing' 'sunbathing' 'swimming']
# Unique elements in Travel_Frequency: [9 3 0 5 1 2 7 8 6 4]
# Unique elements in Vacation_Budget: [3444 1190 2888 ... 3556  790 2641]
# Unique elements in Location: ['urban' 'rural' 'suburban']
# Unique elements in Proximity_to_Mountains: [ 67 261 225 286 198 263 232  40   5  30 224 189 130  34  52  35 214  37
#    9 212  86 292 245 163  72  74 249 134  19 250  85 238 184 165 288 277
#    0 217  11 148 279 153  46 242 284  95 268 256 116 173  25  54 114 118
#  255 223 270 120  78 209  64  22 239 271 135 246 136 197 138 149 298 236
#  287   7  80 137  69  51 146 102  87 142  60 283 180 251 156  79 179 231
#  276  29 226 174 208   6 115 123 260  82 294  70 159 112 216 122  90 293
#  215  58 269 235 210 207 192 257 124 234 248  16 244  50 237 178  62  20
#    8 127  98 107 195 157 200 282  84 171 219  24 166 175  76  13  93 222
#    3  23 299 204 285 183 185  97 104  44 194 182  92 162 188 201 103  47
#  221 227 290 273 211 100 264  88  36 131 213  55   2  73  53  28 155  14
#  158 266 259 296 126  75 170 275 154  43 164 193 199 113 161  99 243  27
#   68 111 132  48 151  41   4 253  57 289  96 144  12 119 203 167 191 143
#   38  21 229 240 196 274 220 181  61 125 176 106 172 141  31 186 241 280
#  168  32  83 140 252 169 267  18 230 145  15 262 152  59  91 295 190 147
#  297 108  49  39 160   1 128 133  56 247  89 187 218 265 202 258  17  10
#   94 272  66 233 228  45 129  71 139  26 281  33  65 254 110 109 278  63
#  150 105 177  77  42 206 117 205 291 121 101  81]
# Unique elements in Proximity_to_Beaches: [ 46  56 282 140 245 100  83 247   3 270 295 202  47  78 297 131 288 272
#  296 260 219 233 177   7 234  37  32 269 274 165  27 168  13  76  98   6
#   79 261 299 241  53 256 244 102 183 213 251  38 275 225 290  49  25 124
#  279 242 179 211  63  90  29 226 205 286  39   2 147 104  22 175 176 172
#   18 259 151 236  97 109 232  28 121 223 120 161 158  52 130 257   5 112
#  273 181  80  91 199  65 262 278  57 126 196 284 137 145 136 106 135  73
#  209 170 164 134 255 132 114 240 210 119 277  68  23 192 157 155 116 281
#   42 110 152 125  67 115  81 221  16 167  40  10 292 254 235 197 142   8
#  289  85 146 127 201  74 173  87 265 229 184 144 206 248  19 108 162 243
#   94 285  45   9 194 228  43 280 207 298  64 141 180 249 294 143 283   1
#   15  14 148 122 113 258 117 186  30 189  55 159 178 163 200 153 214  36
#  111  35 239 267 198  48  31  33 250 182 166 160  50  54 169  66  72  17
#  171  60  86 238  41 293  95 263 271 218 185 118 208  24 230 215  61  26
#  156 224 252 216 227 193 187 103  75 264 231  34  92 123 195 237  44  77
#  212 191 129 217 190  96 266 246 268  84 139 149 150  70  11  58 287 133
#   71 222 138  82 107  12 188  93  59  21 276  20 220 105  89   0  51 154
#  204 253  88 101  62 128   4 291  69 203  99 174]
# Unique elements in Favorite_Season: ['fall' 'summer' 'spring' 'winter']
# Unique elements in Pets: [0 1]
# Unique elements in Environmental_Concerns: [0 1]
# Unique elements in Preference: [0 1]

# %%
x2 = x2.map({'non-binary': 0, 'male': 1, 'female': 2})
x4 = x4.map({'high school': 0, 'bachelor': 1, 'master': 2, 'doctorate': 3})
x5 = x5.map({'hiking': 0, 'skiing': 1, 'sunbathing': 2, 'swimming': 3})
x8 = x8.map({'suburban': 0, 'urban': 1, 'rural': 2})
x11 = x11.map({'summer': 0, 'fall': 1, 'winter': 2, 'spring': 3})

# %% [markdown]
# Zipping all the respectable variables into an Array

# %%
x_array = np.array(list(zip(x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, x13)))
#x_array = x_array.astype(float)
y_array = np.array(y)

# %%
x_array
# Out:
# array([[    38,      2,  34215, ...,      1,      0,      0],
#        [    28,      1,  55820, ...,      1,      1,      1],
#        [    18,      1, 105777, ...,      0,      1,      0],
#        ...,
#        [    64,      1,  66841, ...,      3,      0,      0],
#        [    18,      0,  74638, ...,      1,      1,      1],
#        [    39,      0,  40650, ...,      0,      1,      0]])

# %%
y_array
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# Just in case if there are any NaN values in the array replcae them with '0'

# %%
x_array = np.nan_to_num(x_array, nan=1)
y_array = np.nan_to_num(y_array, nan=1)

# %%
x_array
# Out:
# array([[    38,      2,  34215, ...,      1,      0,      0],
#        [    28,      1,  55820, ...,      1,      1,      1],
#        [    18,      1, 105777, ...,      0,      1,      0],
#        ...,
#        [    64,      1,  66841, ...,      3,      0,      0],
#        [    18,      0,  74638, ...,      1,      1,      1],
#        [    39,      0,  40650, ...,      0,      1,      0]])

# %%
y_array
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# # logistic regression

# %% [markdown]
# Importing all the necessary modules for training the suitable data

# %%
import sklearn
import sklearn.linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, classification_report

# %% [markdown]
# Training the model

# %%
'''Training the model.'''
X_train, X_test, y_train, y_test = train_test_split(x_array, y_array, test_size=0.2, random_state=False)
loR = LogisticRegression()

# %% [markdown]
# Fitting the model.

# %%
loR.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# y predicted value

# %%
y_pred = loR.predict(X_test)

# %% [markdown]
# Print the output

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: \n{accuracy * 100:.2f}")
print()
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))
print()
print("Precision: ")
print(precision_score(y_test, y_pred)*100)
print()
print("\nClassification Report: ")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy:
# 89.30
#
# Confusion Matrix:
# [[7409  398]
#  [ 724 1958]]
#
# Precision:
# 83.106960950764
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93      7807
#            1       0.83      0.73      0.78      2682
#
#     accuracy                           0.89     10489
#    macro avg       0.87      0.84      0.85     10489
# weighted avg       0.89      0.89      0.89     10489

# %% [markdown]
# Create the SMOTE

# %%
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report

sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# %% [markdown]
# Fitting and predicting the value.

# %%
lr = LogisticRegression()
model = lr.fit(X_train_res, y_train_res)
y_pred = model.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: \n{accuracy * 100:.2f}")
print()
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))
print()
print("Precision: ")
print(precision_score(y_test, y_pred)*100)
print()
print("\nClassification Report: ")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy:
# 86.96
#
# Confusion Matrix:
# [[7003  804]
#  [ 564 2118]]
#
# Precision:
# 72.48459958932239
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91      7807
#            1       0.72      0.79      0.76      2682
#
#     accuracy                           0.87     10489
#    macro avg       0.83      0.84      0.83     10489
# weighted avg       0.87      0.87      0.87     10489

# %% [markdown]
# # Perceptron Learning

# %% [markdown]
# Importing the necessary modules

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# Calling Perceptron package through sk-learn

# %%
perceptron = Perceptron(max_iter=1000, tol=1e-3, random_state=42)

# %% [markdown]
# Fitting for perceptron value

# %%
perceptron.fit(X_train, y_train)
# Out:
# Perceptron(random_state=42)

# %% [markdown]
# Prediciting the 'y' value

# %%
y_pred = perceptron.predict(X_test)

# %% [markdown]
# Printing the outputs.

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: \n{accuracy * 100:.2f}")
print()
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))
print()
print("Precision: ")
print(precision_score(y_test, y_pred)*100)
print()
print("\nClassification Report: ")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy:
# 74.34
#
# Confusion Matrix:
# [[7718   89]
#  [2603   79]]
#
# Precision:
# 47.023809523809526
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.99      0.85      7807
#            1       0.47      0.03      0.06      2682
#
#     accuracy                           0.74     10489
#    macro avg       0.61      0.51      0.45     10489
# weighted avg       0.68      0.74      0.65     10489

# %% [markdown]
# Creating the SMOTE

# %%
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report

sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# %% [markdown]
# Predicting the y value and fitting it

# %%
per = Perceptron()
percep = per.fit(X_train_res, y_train_res)
y_pred = percep.predict(X_test)

# %% [markdown]
# # SVM - Support Vector Machine

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Standard Scaling the training and testing data

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Creating the SVM model from sk-learn

# %%
svm = SVC(kernel='linear', random_state=42)

# %% [markdown]
# Fitting the value

# %%
svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %% [markdown]
# Predicting the y value

# %%
y_pred = svm.predict(X_test)

# %% [markdown]
# Printing the outputa

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: \n{accuracy * 100:.2f}")
print()
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))
print()
print("Precision: ")
print(precision_score(y_test, y_pred)*100)
print()
print("\nClassification Report: ")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy:
# 90.01
#
# Confusion Matrix:
# [[7373  434]
#  [ 614 2068]]
#
# Precision:
# 82.65387689848122
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      7807
#            1       0.83      0.77      0.80      2682
#
#     accuracy                           0.90     10489
#    macro avg       0.87      0.86      0.87     10489
# weighted avg       0.90      0.90      0.90     10489

# %% [markdown]
# Creating the SMOTE

# %%
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report

sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# %%
svm = SVC()
svm_mod = svm.fit(X_train_res, y_train_res)
y_pred = svm_mod.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: \n{accuracy * 100:.2f}")
print()
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))
print()
print("Precision: ")
print(precision_score(y_test, y_pred)*100)
print()
print("\nClassification Report: ")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy:
# 98.89
#
# Confusion Matrix:
# [[7718   89]
#  [  27 2655]]
#
# Precision:
# 96.75655976676384
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      7807
#            1       0.97      0.99      0.98      2682
#
#     accuracy                           0.99     10489
#    macro avg       0.98      0.99      0.99     10489
# weighted avg       0.99      0.99      0.99     10489

# %% [markdown]
# # KNN

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score
from sklearn.datasets import load_iris

# %% [markdown]
# Calling out the KNN Model

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# Fitting the KNN Value

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# Prediciting the y value

# %%
y_pred = knn.predict(X_test)

# %% [markdown]
# Printing the outputs

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: \n{accuracy * 100:.2f}")
print()
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))
print()
print("Precision: ")
print(precision_score(y_test, y_pred)*100)
print()
print("\nClassification Report: ")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy:
# 91.21
#
# Confusion Matrix:
# [[7444  363]
#  [ 559 2123]]
#
# Precision:
# 85.39823008849558
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94      7807
#            1       0.85      0.79      0.82      2682
#
#     accuracy                           0.91     10489
#    macro avg       0.89      0.87      0.88     10489
# weighted avg       0.91      0.91      0.91     10489

# %% [markdown]
# Creating the SMOTE

# %%
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report

sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# %%
knn1 = KNeighborsClassifier()
knn_mod = knn1.fit(X_train_res, y_train_res)
y_pred = knn_mod.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: \n{accuracy * 100:.2f}")
print()
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))
print()
print("Precision: ")
print(precision_score(y_test, y_pred)*100)
print()
print("\nClassification Report: ")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy:
# 88.04
#
# Confusion Matrix:
# [[6713 1094]
#  [ 160 2522]]
#
# Precision:
# 69.74557522123894
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.91      7807
#            1       0.70      0.94      0.80      2682
#
#     accuracy                           0.88     10489
#    macro avg       0.84      0.90      0.86     10489
# weighted avg       0.91      0.88      0.89     10489

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, roc_curve, auc, ConfusionMatrixDisplay

# %%
# Histogram for each feature
df1.hist(bins=15, figsize=(15, 10), layout=(3, 3))
plt.suptitle("Feature Distributions")
plt.show()

# Box plot for each feature
plt.figure(figsize=(15, 6))
plt.show()

# %%
# Confusion matrix plot
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %%
y_proba = model.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f"ROC curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.show()
